# %%
from bs4 import BeautifulSoup, Tag
import numpy as np
from string import printable, ascii_letters, punctuation, digits
import requests
import csv
import time
from glob import glob

# %% [markdown]
# ## Helper Functions

# %%
BASE_URL = 'http://bahiker.com'

AREAS = {
    'northbayhikes': 'North Bay',
    'southbayhikes': 'South Bay',
    'sfhikes': 'San Francisco',
    'eastbayhikes': 'East Bay',
}

DEPARTMENTS = {
    'CCWD':'Contra Costa Water District',
    'CSMP':'County of San Mateo Parks Department ',
    'CSP':'California State Parks',
    'EBRPD':'East Bay Regional Park District',
    'GGNRA':'Golden Gate National Recreation Area',
    'MCOSD':'Marin County Open Space District',
    'MROSD':'Midpeninsula Regional Open Space District',
    'MMWD':'Marin Municipal Water District',
    'NPS':'National Park Service',
    'SCCP':'Santa Clara County Parks',
    'SLT':'Solano Land Trust',
}

HIKE_INFO_PATHS = {
    'title': '/title.html',
    'location': '/location.html',
    'sidebar': '/sidebar.html',
}


def clean_text(instr):
    acceptable_letters = ascii_letters + ' ' + punctuation + digits
    return ''.join([x if x in acceptable_letters else '' for x in instr])


def get_county(inelem):
    if type(inelem) == str:
        if 'county' in [e.lower() for e in inelem.split()]:
            return inelem.strip()
    elif type(inelem) == list:
        for elem in inelem:
            if get_county(elem):
                return elem.strip()


def get_department(inelem):
    if type(inelem) == str:
        department = DEPARTMENTS.get(inelem.strip())
        if department:
            return department.strip()            
    elif type(inelem) == list:
        for elem in inelem:
            department = get_department(elem)
            if department:
                return department

# %% [markdown]
# ## Process Raw
# ### All Trails

# %%
soup = ''
with open('raw/trails.html', 'rb') as trails:
    soup = BeautifulSoup(trails, 'lxml')

# %%
all_trails = []
failures = []
for trail in soup.findAll('a'):
    # Ignore homepage links
    if trail.attrs['href'] != '/':
        try:
            extra_info = [clean_text(e) for e in trail.next.next.split(',')][1:]
        except TypeError as t:
            failures.append(t)
        all_trails.append({
                'uri': trail.attrs['href'],
                'name': clean_text(trail.text),
                'area': trail.attrs['href'][:trail.attrs['href'].find('/')],
                'county': get_county(extra_info),
                'park_department': get_department(extra_info),
            })

# %%
all_trails
# Out:
# [{'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Abbotts Lagoon Trail',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/abbottslagoon.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Acorn Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/arastradero.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Baylands Preserve',
#   'park_department': None,
#   'uri': 'southbayhikes/baylands.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Hidden Villa',
#   'park_department': None,
#   'uri': 'southbayhikes/hiddenvilla.html'},
#  {'area': 'southbayhikes',
#   'county': 'Wunderlich County Park',
#   'name': 'Alambique Trail',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/wunderlich.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Coyote Hills Regional Park',
#   'park_department': None,
#   'uri': 'eastbayhikes/coyotehills.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Quarry Lakes Regional Recreation Area',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/quarrylakes.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Alamo Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/diablofoothills.html'},
#  {'area': 'southbayhikes',
#   'county': 'Uvas Canyon County Park',
#   'name': 'Alec Cayon Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/uvas.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Alexander Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/invalley.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Alpine Pond Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/skylinealpine.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Alpine Road',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/coal.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Alpine Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/cmr.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County Parks',
#   'name': 'Alta Vista Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/foothill.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Alto Bowl Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/altobowl.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Ancient Oaks Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/russianridge.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Anniversary Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/whsrhg.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Ao Nuevo Point Trail',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/anonuevo2.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Ao Nuevo Trail',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/butano.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Aquinas Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/elsereno.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Solano County',
#   'name': 'Arch Trail',
#   'park_department': None,
#   'uri': 'eastbayhikes/rockville.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Arrowhead Marsh Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/mlkshoreline.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County Parks',
#   'name': 'Arroyo Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/hputnam.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'Austin Creek Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/austincreek.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Azalea Meadow Trail',
#   'park_department': 'Marin Municipal Water District',
#   'uri': 'northbayhikes/rockspring.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Bald Hill Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/deerpark.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Bald Knob Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/purisimabald.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Bald Mountain Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/sierraazul/sierraazul.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': ' Bald Mountain Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/sugarloaf.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Barnabe Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/sptbarnabe.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'Bald Mountain Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/sugarloaf.html'},
#  {'area': 'sfhikes',
#   'county': 'San Francisco County',
#   'name': 'Bay Area Ridge Trail',
#   'park_department': None,
#   'uri': 'sfhikes/funston.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Solano County',
#   'name': 'Bay Area Ridge Trail',
#   'park_department': None,
#   'uri': 'eastbayhikes/rockville.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Big Trees Trail',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/indiantree.html'},
#  {'area': 'northbayhikes',
#   'county': 'Napa County',
#   'name': 'Buckeye Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/skylinewild.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'California Riding and Hiking Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/carquinez.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Cobblestone Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/burdell.html'},
#  {'area': 'southbayhikes',
#   'county': None,
#   'name': 'Coyote Peak Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/santateresa.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Craig Britton Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/purisimahiggins.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Deer Camp Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/burdell.html'},
#  {'area': 'northbayhikes',
#   'county': None,
#   'name': 'Deer Park Fire Road',
#   'park_department': None,
#   'uri': 'northbayhikes/muirwoodsroad.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Doe Hill Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/little.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Eagle Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/missionpeak.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Grass Valley Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/bortmeadow.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Teresa County Park',
#   'name': 'Hidden Springs Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/santateresa.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Solano County',
#   'name': 'Hiddenbrooke Trail',
#   'park_department': None,
#   'uri': 'eastbayhikes/hiddenbrooke.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Huckleberry Path',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/huckleberry.htm'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'Lake Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/jacklondon.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Little Mountain Trail',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/little.html'},
#  {'area': 'southbayhikes',
#   'county': 'Marin County',
#   'name': 'Lost ',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'southbayhikes/windy.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/windy.html'},
#  {'area': 'southbayhikes',
#   'county': 'Mount Madonna County Park',
#   'name': 'Merry Go Round Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/madonna.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Middle Burdell Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/burdell.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Teresa County Park',
#   'name': 'Mine Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/santateresa.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'Mountain Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/jacklondon.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'North Ridge Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/purisimanorth.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Peters Creek Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/longridge.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Redwood Creek Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/muirwoodsroad.html'},
#  {'area': 'northbayhikes',
#   'county': None,
#   'name': 'Ridge Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/hputnam.html'},
#  {'area': 'southbayhikes',
#   'county': None,
#   'name': 'Ridge Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/russianridge.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Ridge Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/skyline1.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'San Andreas Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/burdell.html'},
#  {'area': 'southbayhikes',
#   'county': 'Upper Steven Creek County Park',
#   'name': 'Saratoga Gap Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/usccp.html'},
#  {'area': 'southbayhikes',
#   'county': 'SanbornSkyline County Park',
#   'name': 'Skyline Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/sanborn.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Skywalker Easement',
#   'park_department': None,
#   'uri': 'northbayhikes/skywalker.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Sobrante Ridge Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/sobrante.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'Sonoma Ridge Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/jacklondon.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Stile Ranch Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/stileranch.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Sweeney Ridge Trail',
#   'park_department': 'Golden Gate National Recreation Area',
#   'uri': 'southbayhikes/sweeney.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'West Ridge Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/redwood.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Woods Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/sierraazul/sierraazul2.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Bay Hills Fire Road',
#   'park_department': None,
#   'uri': 'northbayhikes/barbier.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Bair Island',
#   'park_department': None,
#   'uri': 'southbayhikes/bair.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Bothin Marsh Open Space Preserve',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/bothin.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Cesar ChavezNorth Waterfront Park',
#   'park_department': None,
#   'uri': 'eastbayhikes/nwaterfront.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Coyote Hills Regional Park',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/coyotehills.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Coyote Point Recreation Area',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/coyotepoint.html'},
#  {'area': 'sfhikes',
#   'county': 'San Francisco County',
#   'name': 'Crissy Field',
#   'park_department': None,
#   'uri': 'sfhikes/crissy.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Don Edwards San Francisco Bay National Wildlife Refuge',
#   'park_department': None,
#   'uri': 'eastbayhikes/dewf.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Hayward Regional Shoreline',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/hrs.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Oyster Point Regional Shoreline',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/oyster.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Point Isabel Regional Shoreline',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/ptisabel.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Ravenswood Open Space Preserve',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/ravenswood.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Shoreline at Mountain View',
#   'park_department': None,
#   'uri': 'southbayhikes/shoreline.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'Tubbs Island',
#   'park_department': None,
#   'uri': 'northbayhikes/tubbs.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Bay View Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/pointpinole.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Bayview Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/coyotehills.html'},
#  {'area': 'southbayhikes',
#   'county': 'Wunderlich County Park',
#   'name': 'Bear Gulch Trail',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/wunderlich.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Bear Valley Trail',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/prbv.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Belgum Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/wildcatcanyon.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Bella Vista Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/monte.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Cruz County',
#   'name': 'Bennett Creek Trail',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/fallcreek.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Benstein Trail',
#   'park_department': 'Marin Municipal Water District',
#   'uri': 'northbayhikes/rockspring.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Cruz County',
#   'name': 'Berry Creek Falls from the ocean',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/bbrdo.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Cruz County',
#   'name': 'Waterfall Loop from Park Headquarters',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/bigbasin/waterfallloop.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Bicentennial Bike Path',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/bothin.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Cruz County',
#   'name': 'Big Ben Trail',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/fallcreek.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Big Canyon Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/ebcp.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Big Rock Ridge Fire Road',
#   'park_department': None,
#   'uri': 'northbayhikes/lucasvalley.html'},
#  {'area': 'southbayhikes',
#   'county': 'Sam McDonald County Park',
#   'name': 'Big Tree Trail',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/smcp.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Cruz County',
#   'name': 'Big Trees Nature Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/lochlomond.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Big Trees Trail',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/indiantree.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County Parks',
#   'name': 'Bigleaf Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/shiloh.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Bills Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/sptbarnabe.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Black Diamond Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/bdm.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Black Hills Trail',
#   'park_department': 'Contra Costa Water District',
#   'uri': 'eastbayhikes/losvaqueros.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Black Mountain Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/ranchoblack.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Bear Creek Staging Area Briones Regional Park',
#   'park_department': None,
#   'uri': 'eastbayhikes/bcbriones.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Kennedy Grove Regional Recreation Area',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/kengrove.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County Parks',
#   'name': 'Blackberry Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/ragle.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Blithedale Ridge Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/blithe.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Morgan Territory Regional Preserve',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/morgan.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Pulgas Ridge Open Space Preserve',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/pulgas.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Bob Middagh Trail',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/altobowl.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Bob Walker Regional Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/morgan.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Bobcat Trail',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/gerbode.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'Bodega Head Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/bodegahead.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Bruno Mountain County and State Park',
#   'name': 'All Access Loop',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/sanbrunoaccess.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Bruno Mountain County and State Park',
#   'name': 'Bog Loop',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/sanbrunobog.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Bolema Trail',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/fivebrooks.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Bootjack Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/mountainhome.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Borden Hatch Mill Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/purisimabald.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Bothin Access Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/white.html'},
#  {'area': 'southbayhikes',
#   'county': 'Pescadero Creek County Park',
#   'name': 'Bridge Trail',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/portola.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Briones Crest Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/bcbriones.html'},
#  {'area': 'eastbayhikes',
#   'county': None,
#   'name': 'Briones to Mount Diablo Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/diablofoothills.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Brooks Falls Trail',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/sanpedro.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Bort Meadow Staging Area Anthony Chabot Regional Park',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/bortmeadow.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Deer Park Trailhead',
#   'park_department': None,
#   'uri': 'northbayhikes/deerpark.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Junipero Serra County Park',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/juniperoserra.html'},
#  {'area': 'northbayhikes',
#   'county': 'Napa County',
#   'name': 'Skyline Wilderness Park',
#   'park_department': None,
#   'uri': 'northbayhikes/skylinewild.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Bunny Creek Loop Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/hiddenvilla.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Burdell Mountain Ridge Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/burdell.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Buzzard Burn Access',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/invalley.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'California Riding and Hiking Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/carquinez.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Californio Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/quarrylakes.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Camp Eastwood Road',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/mountainhome.html'},
#  {'area': 'southbayhikes',
#   'county': 'Grant County Park',
#   'name': 'Caada de Pala Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/grant.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Caada Trail',
#   'park_department': 'Contra Costa Water District',
#   'uri': 'eastbayhikes/losvaqueros.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Canyon Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/monte.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Canyon View Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/sunol.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Cardinet Oaks Road',
#   'park_department': 'California State Parks',
#   'uri': 'eastbayhikes/mdsp/donnercanyon.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Carquinez Overlook Loop Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/carquinezwest.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Cascade Falls Trail',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/cascade.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Cascade Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/cascade.html'},
#  {'area': 'southbayhikes',
#   'county': 'Almaden Quicksilver County Park',
#   'name': 'Castillero Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/almadenquicksilver.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Cruz County',
#   'name': 'Castle Rock Trail',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/castlerock.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Up to the falls',
#   'park_department': 'Marin Municipal Water District',
#   'uri': 'northbayhikes/cataractfalls.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Rock SpringPotrero Meadow Loop',
#   'park_department': 'Marin Municipal Water District',
#   'uri': 'northbayhikes/rockspring.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Cave Rocks Road',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/sunol.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Cemetery Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/tlsh.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Chamise Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/ranchoduveneck.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': ' Chaparral Loop',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/bdm.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Joaquin Miller Park',
#   'park_department': None,
#   'uri': 'eastbayhikes/joaquinmiller.html'},
#  {'area': 'northbayhikes',
#   'county': 'Napa County',
#   'name': 'Skyline Wilderness Park',
#   'park_department': None,
#   'uri': 'northbayhikes/skylinewild.html'},
#  {'area': 'southbayhikes',
#   'county': 'Upper Steven Creek County Park',
#   'name': 'Charcoal Road',
#   'park_department': None,
#   'uri': 'southbayhikes/usccp.html'},
#  {'area': 'southbayhikes',
#   'county': 'Huddart County Park',
#   'name': 'Chickadee Trail',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/huddartchick.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Chicken Shack Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/pv.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Chimney Rock Trail',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/chimneyrock.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Chochenyo Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/coyotehills.html'},
#  {'area': 'southbayhikes',
#   'county': 'Almaden Quicksilver County Park',
#   'name': 'Church Hill Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/almadenquicksilver.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Citron Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/kingmtn.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Bear Valley Trailhead',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/prbv.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Palomarin Trailhead',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/palomarin.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Muir Beach Trailhead',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/muirbeach.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Muir Woods Road Trailhead',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/muirwoodsroad.html'},
#  {'area': 'sfhikes',
#   'county': 'San Francisco County',
#   'name': 'Lands End',
#   'park_department': 'Golden Gate National Recreation Area',
#   'uri': 'sfhikes/landsend.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Rodeo Beach Trailhead',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/rodeobeach.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Cobblestone Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/burdell.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'Cobblestone Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/annadel/annadel2.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Conifer Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/giacomini.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Contra Costa Canal Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/ccct.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Cooks Point Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/pointpinole.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Cora Older Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/fremontolder.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Cordilleras Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/pulgas.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Corral Trail',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/henrycoe/headquarters.html'},
#  {'area': 'northbayhikes',
#   'county': 'Napa County',
#   'name': 'BotheNapa Valley State Park',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/bothenapa.htm'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Santa Teresa County Park',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/santateresa.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Muir Beach Trailhead',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/muirbeach.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Stevens Creek County Park',
#   'park_department': None,
#   'uri': 'southbayhikes/stevenscreek.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Coyote Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/morgan.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Craig Britton Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/purisimahiggins.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Crazy Petes Road',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/coal.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County Parks',
#   'name': 'Crane Creek Regional Park',
#   'park_department': None,
#   'uri': 'northbayhikes/crane.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Villa Montalvo County Park',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/montalvo.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Fremont Older Open Space Preserve',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/fremontolder.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County Parks',
#   'name': 'Shiloh Ranch Regional Park',
#   'park_department': None,
#   'uri': 'northbayhikes/shiloh.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Crest Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/millerknox.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Cross Marin Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/sptbarnabe.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Huddart County Park',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/huddartdean.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'as a gateway to Phleger Estate',
#   'park_department': 'Golden Gate National Recreation Area',
#   'uri': 'southbayhikes/phleger.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'to Pulgas Water Temple',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/pwt.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Cuesta Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/lastrampas.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Curran Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/tilden.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Curry Canyon Road',
#   'park_department': 'California State Parks',
#   'uri': 'eastbayhikes/mdsp/diablocurry.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Bruno Mountain County and State Park',
#   'name': 'Dairy Ravine Trail',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/sanbrunosummit.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Dawn Falls Trail',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/baltcanyon.html'},
#  {'area': 'southbayhikes',
#   'county': 'Junipero Serra County Park',
#   'name': 'De Anza Trail',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/juniperoserra.html'},
#  {'area': 'southbayhikes',
#   'county': 'Huddart County Park',
#   'name': 'Dean Trail',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/huddartdean.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Deer Camp Cutoff Trail',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/indiantree.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Deer Camp Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/burdell.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Deer Camp Trail',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/indiantree.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Deer Island Loop Trail',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/deerisland.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Deer Park Trailhead',
#   'park_department': None,
#   'uri': 'northbayhikes/deerpark.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Muir Woods Road Trailhead',
#   'park_department': None,
#   'uri': 'northbayhikes/muirwoodsroad.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Deer Park Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/deerpark.html'},
#  {'area': 'northbayhikes',
#   'county': 'Napa County',
#   'name': 'Deer Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/westwoodhills.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Devils Gulch Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/sptdevil.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Dipsea Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/stinson.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'Discovery Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/armstrong.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Doe Hill Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/little.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Donner Canyon Road',
#   'park_department': 'California State Parks',
#   'uri': 'eastbayhikes/mdsp/donnercanyon.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Cruz County',
#   'name': 'Dool Trail',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/bigbasin/waterfallloop.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'GarinDry Creek Pioneer Parks',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/garin.html'},
#  {'area': 'northbayhikes',
#   'county': 'Napa County',
#   'name': 'Alston Park',
#   'park_department': None,
#   'uri': 'northbayhikes/alstonpark.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'DUST Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/coyotehills.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Eagle Crest Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/delvalle.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Eagle Peak Trail',
#   'park_department': None,
#   'uri': 'eastbayhikes/mdsp/mcep.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Ignacio Valley Open Space Preserve',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/ignacio.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Mission Peak Regional Preserve',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/missionpeak.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'Armstrong Redwoods State Reserve',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/armstrong.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Redwood Regional Park',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/redwood.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'East Shore Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/delvalle.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Easy Grade Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/pantoll.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Eaton Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/ebcp.html'},
#  {'area': 'sfhikes',
#   'county': 'San Francisco County',
#   'name': 'Ecology Trail',
#   'park_department': 'National Park Service',
#   'uri': 'sfhikes/inspoint.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'El Corte de Madera Creek Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/ecdmsp.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Elderberry Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/lastrampas.html'},
#  {'area': 'southbayhikes',
#   'county': 'Almaden Quicksilver County Park',
#   'name': 'English Camp Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/almadenquicksilver.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Escalon Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/caminoalto.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Estero Trailhead',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/estero.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Muddy Hollow Trailhead',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/muddy.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Bruno Mountain County and State Park',
#   'name': 'Eucalyptus Loop Trail',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/sanbrunosummit.html'},
#  {'area': 'sfhikes',
#   'county': 'San Francisco County',
#   'name': 'Fairy Gates Trail',
#   'park_department': None,
#   'uri': 'sfhikes/sutro.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Cruz County',
#   'name': 'Fall Creek Trail',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/fallcreek.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Falls Trail',
#   'park_department': 'California State Parks',
#   'uri': 'eastbayhikes/mdsp/donnercanyon.html'},
#  {'area': 'northbayhikes',
#   'county': None,
#   'name': 'Fern Creek Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/mountainhome.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County Parks',
#   'name': 'Fiddleneck Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/crane.html'},
#  {'area': 'southbayhikes',
#   'county': 'Calero County Park',
#   'name': 'Figueroa Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/calero.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Resolution Loop',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/ecdmsp.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Tafoni Loop',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/elcortemadera.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Fire Interpretive Trail',
#   'park_department': 'California State Parks',
#   'uri': 'eastbayhikes/mdsp/diablosummit.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Flag Hill RoadTrail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/sunol.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Flat Frog Trail',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/henrycoe/headquarters.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Foothills Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/diablofoothills.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Teresa County Park',
#   'name': 'Fortini Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/stileranch.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo  Santa Clara County',
#   'name': 'Franciscan Loop Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/lostrancos.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Franklin Ridge Loop Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/carquinez.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Gateway Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/arastradero.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Cruz County',
#   'name': 'Gilchrist Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/lochlomond.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'Gilliam Creek Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/austincreek.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Cruz County',
#   'name': 'Glen Corrie Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/lochlomond.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Glen Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/lomaalta.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Glenbrook Trail',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/muddy.html'},
#  {'area': 'sfhikes',
#   'county': 'San Francisco County',
#   'name': 'Golden Gate Promenade',
#   'park_department': None,
#   'uri': 'sfhikes/crissy.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Goldenrod Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/bortmeadow.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Grabtown Gulch Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/purisimabald.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Grapevine Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/hiddenvilla.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Grass Valley Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/bortmeadow.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'Gray Pine Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/sugarloaf.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Gray Whale Cove Trail',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/mcneeranch.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Grayfox Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/bishop.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Green Gulch Trail',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/muirbeach.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Griffin Loop Trail',
#   'park_department': None,
# ...
#   'name': 'A loop around Sausal Pond',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/windysausal.html'},
#  {'area': 'northbayhikes',
#   'county': 'Stafford Lake County Park',
#   'name': 'Stafford Lake Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/little.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Steep Ravine Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/stinson.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'Steves S Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/annadel/annadel.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Stevens Creek Nature Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/monte.html'},
#  {'area': 'southbayhikes',
#   'county': 'Stevens Creek County Park',
#   'name': 'Stevens Creek Tony Look Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/stevenscreek.html'},
#  {'area': 'northbayhikes',
#   'county': 'Napa County',
#   'name': 'Stevenson Memorial Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/rlssp.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Stewart Trail',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/fivebrooks.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Stewartsville Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/bdm.html'},
#  {'area': 'southbayhikes',
#   'county': None,
#   'name': 'Stile Ranch Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/stileranch.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Stocking Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/bontempe.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Stone Corral Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/morgan.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Stonegate Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/diablofoothills.html'},
#  {'area': 'eastbayhikes',
#   'county': None,
#   'name': 'Stream Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/redwood.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Stream View Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/bishop.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Bruno Mountain County and State Park',
#   'name': 'Summit Loop Trail',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/sanbrunosummit.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Sunny Jim  Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/skyline1.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Sunset Beach Trail',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/estero.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Angel Island State Park',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/angelisland.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Cruz County',
#   'name': 'Big Basin Redwoods State Park',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/bigbasin/waterfallloop.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Joaquin Miller Park',
#   'park_department': None,
#   'uri': 'eastbayhikes/joaquinmiller.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Sweeney Ridge Trail',
#   'park_department': 'Golden Gate National Recreation Area',
#   'uri': 'southbayhikes/sweeney.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Sylvan Trail',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/edgewood.html'},
#  {'area': 'southbayhikes',
#   'county': 'Upper Stevens Creek County Park',
#   'name': 'Table Mountain Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/usccp.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Resolution Loop',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/ecdmsp.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Tafoni Loop',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/elcortemadera.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Terra Linda Ridge Fire Road',
#   'park_department': None,
#   'uri': 'northbayhikes/tlshdnorth.html'},
#  {'area': 'northbayhikes',
#   'county': 'Stafford Lake County Park',
#   'name': 'Terwilliger Nature Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/staffordlk.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Thermalito Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/pleasanton.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Thorner Ridge Trail',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/thorner.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County Parks',
#   'name': 'Three Lakes Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/foothill.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County Parks',
#   'name': 'Three Meadows Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/maxwell.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Tidelands Trail',
#   'park_department': None,
#   'uri': 'eastbayhikes/dewf.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Tomahawk Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/tlsh.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Tomales Point Trail',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/tomalespt.html'},
#  {'area': 'southbayhikes',
#   'county': 'Sam McDonald County Park',
#   'name': 'Towne Trail',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/smcp.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Toyon Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/cmr.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'Treadmill Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/jacklondon.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Tres Sendas Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/redwood.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Trestle Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/mountainhome.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Troop  Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/mountainhome.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Cruz County',
#   'name': 'Truck Trail',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/fallcreek.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Cruz County',
#   'name': 'Twin Oaks Trail',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/wilder.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Upper Meadow Trail',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/indiantree.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Upper Sea Foam Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/kengrove.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Upper Summit Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/caminoalto.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Upper Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/lastrampas.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Upper Wildcat Canyon Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/rancho.html'},
#  {'area': 'southbayhikes',
#   'county': 'Calero County Park',
#   'name': 'Vallecito Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/calero.html'},
#  {'area': 'northbayhikes',
#   'county': 'Napa County',
#   'name': 'Alston Park',
#   'park_department': None,
#   'uri': 'northbayhikes/alstonpark.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Los Vaqueros Watershed',
#   'park_department': 'Contra Costa Water District',
#   'uri': 'eastbayhikes/losvaqueros.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'San Pedro Valley Park',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/sanpedrovvl.html'},
#  {'area': 'northbayhikes',
#   'county': 'Napa County',
#   'name': 'Westwood Hills Park',
#   'park_department': None,
#   'uri': 'northbayhikes/westwoodhills.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County Parks',
#   'name': 'Verano Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/maxwell.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Verissimo Hills Trail',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/little.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Verna Dunshee Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/eastpeak.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Vista Loop Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/stevenscreek.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Volcanic Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/sibley.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Volvon Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/morgan.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'W Richardson Trail',
#   'park_department': 'California State Parks',
#   'uri': 'northbayhikes/annadel/annadel.html'},
#  {'area': 'southbayhikes',
#   'county': 'Uvas Canyon County Park',
#   'name': 'Waterfall Loop Fire Road',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/uvas.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Hazelnut Trail Loop',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/sanpedrohazel.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Valley View Loop',
#   'park_department': 'County of San Mateo Parks Department',
#   'uri': 'southbayhikes/sanpedrovvl.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'West Ridge Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/millerknox.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Western Pacific Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/quarrylakes.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County Parks',
#   'name': 'Westside Trail',
#   'park_department': None,
#   'uri': 'northbayhikes/foothill.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'White Hill Fire Road',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/white.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'White Oak Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/monte.html'},
#  {'area': 'southbayhikes',
#   'county': None,
#   'name': 'Whitehouse Ridge Trail',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/anonuevo.html'},
#  {'area': 'southbayhikes',
#   'county': 'San Mateo County',
#   'name': 'Wilburs Watch',
#   'park_department': None,
#   'uri': 'southbayhikes/wilburswatch.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Wildcat Canyon Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/rancho.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Wildcat Creek Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/wildcatcanyon.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Contra Costa County',
#   'name': 'Wildcat Peak Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/tilden.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Wildcat Trail',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/invalley.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Cruz County',
#   'name': 'Wilder Ridge Loop Trail',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/wilder.html'},
#  {'area': 'northbayhikes',
#   'county': 'Sonoma County',
#   'name': 'Wingspan Way',
#   'park_department': None,
#   'uri': 'northbayhikes/tubbs.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Wolf Ridge Trail',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/rodeobeach.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Wood Duck Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/quarrylakes.html'},
#  {'area': 'eastbayhikes',
#   'county': 'Alameda County',
#   'name': 'Woodland Trail',
#   'park_department': 'East Bay Regional Park District',
#   'uri': 'eastbayhikes/pleasanton.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Woodoaks Trail',
#   'park_department': 'Marin County Open Space District',
#   'uri': 'northbayhikes/sanpedro.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Woodrat Trail',
#   'park_department': None,
#   'uri': 'southbayhikes/arastradero.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Woods Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/sierraazul/sierraazul2.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Worn Spring Fire Road',
#   'park_department': None,
#   'uri': 'northbayhikes/deerpark.html'},
#  {'area': 'southbayhikes',
#   'county': 'Grant County Park',
#   'name': 'Yerba Buena Trail',
#   'park_department': 'Santa Clara County Parks',
#   'uri': 'southbayhikes/grant.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Phoenix Lake Trailhead',
#   'park_department': None,
#   'uri': 'northbayhikes/phoenixlake.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Deer Park Trailhead',
#   'park_department': None,
#   'uri': 'northbayhikes/deerpark.html'},
#  {'area': 'northbayhikes',
#   'county': 'Marin County',
#   'name': 'Z Ranch Trail',
#   'park_department': 'National Park Service',
#   'uri': 'northbayhikes/prsky.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Cruz County',
#   'name': 'Zane Gray Cutoff',
#   'park_department': 'California State Parks',
#   'uri': 'southbayhikes/wilder.html'},
#  {'area': 'southbayhikes',
#   'county': 'Santa Clara County',
#   'name': 'Zinfandel Trail',
#   'park_department': 'Midpeninsula Regional Open Space District',
#   'uri': 'southbayhikes/picchetti.html'}]

# %%
with open('all_trails.csv', 'w') as csvfile:
    fieldnames = all_trails[1].keys()
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for trail in all_trails:
        writer.writerow(trail)

# %% [markdown]
# ### Fetch Hike Sidebars

# %%
trails_paths = [t['uri'] for t in all_trails]
trails_paths
# Out:
# ['northbayhikes/abbottslagoon.html',
#  'southbayhikes/arastradero.html',
#  'southbayhikes/baylands.html',
#  'southbayhikes/hiddenvilla.html',
#  'southbayhikes/wunderlich.html',
#  'eastbayhikes/coyotehills.html',
#  'eastbayhikes/quarrylakes.html',
#  'eastbayhikes/diablofoothills.html',
#  'southbayhikes/uvas.html',
#  'northbayhikes/invalley.html',
#  'southbayhikes/skylinealpine.html',
#  'southbayhikes/coal.html',
#  'southbayhikes/cmr.html',
#  'northbayhikes/foothill.html',
#  'northbayhikes/altobowl.html',
#  'southbayhikes/russianridge.html',
#  'southbayhikes/whsrhg.html',
#  'southbayhikes/anonuevo2.html',
#  'southbayhikes/butano.html',
#  'southbayhikes/elsereno.html',
#  'eastbayhikes/rockville.html',
#  'eastbayhikes/mlkshoreline.html',
#  'northbayhikes/hputnam.html',
#  'northbayhikes/austincreek.html',
#  'northbayhikes/rockspring.html',
#  'northbayhikes/deerpark.html',
#  'southbayhikes/purisimabald.html',
#  'southbayhikes/sierraazul/sierraazul.html',
#  'northbayhikes/sugarloaf.html',
#  'northbayhikes/sptbarnabe.html',
#  'northbayhikes/sugarloaf.html',
#  'sfhikes/funston.html',
#  'eastbayhikes/rockville.html',
#  'northbayhikes/indiantree.html',
#  'northbayhikes/skylinewild.html',
#  'eastbayhikes/carquinez.html',
#  'northbayhikes/burdell.html',
#  'southbayhikes/santateresa.html',
#  'southbayhikes/purisimahiggins.html',
#  'northbayhikes/burdell.html',
#  'northbayhikes/muirwoodsroad.html',
#  'northbayhikes/little.html',
#  'eastbayhikes/missionpeak.html',
#  'eastbayhikes/bortmeadow.html',
#  'southbayhikes/santateresa.html',
#  'eastbayhikes/hiddenbrooke.html',
#  'eastbayhikes/huckleberry.htm',
#  'northbayhikes/jacklondon.html',
#  'northbayhikes/little.html',
#  'southbayhikes/windy.html',
#  'southbayhikes/windy.html',
#  'southbayhikes/madonna.html',
#  'northbayhikes/burdell.html',
#  'southbayhikes/santateresa.html',
#  'northbayhikes/jacklondon.html',
#  'southbayhikes/purisimanorth.html',
#  'southbayhikes/longridge.html',
#  'northbayhikes/muirwoodsroad.html',
#  'northbayhikes/hputnam.html',
#  'southbayhikes/russianridge.html',
#  'southbayhikes/skyline1.html',
#  'northbayhikes/burdell.html',
#  'southbayhikes/usccp.html',
#  'southbayhikes/sanborn.html',
#  'northbayhikes/skywalker.html',
#  'eastbayhikes/sobrante.html',
#  'northbayhikes/jacklondon.html',
#  'southbayhikes/stileranch.html',
#  'southbayhikes/sweeney.html',
#  'eastbayhikes/redwood.html',
#  'southbayhikes/sierraazul/sierraazul2.html',
#  'northbayhikes/barbier.html',
#  'southbayhikes/bair.html',
#  'northbayhikes/bothin.html',
#  'eastbayhikes/nwaterfront.html',
#  'eastbayhikes/coyotehills.html',
#  'southbayhikes/coyotepoint.html',
#  'sfhikes/crissy.html',
#  'eastbayhikes/dewf.html',
#  'eastbayhikes/hrs.html',
#  'eastbayhikes/oyster.html',
#  'eastbayhikes/ptisabel.html',
#  'southbayhikes/ravenswood.html',
#  'southbayhikes/shoreline.html',
#  'northbayhikes/tubbs.html',
#  'eastbayhikes/pointpinole.html',
#  'eastbayhikes/coyotehills.html',
#  'southbayhikes/wunderlich.html',
#  'northbayhikes/prbv.html',
#  'eastbayhikes/wildcatcanyon.html',
#  'southbayhikes/monte.html',
#  'southbayhikes/fallcreek.html',
#  'northbayhikes/rockspring.html',
#  'southbayhikes/bbrdo.html',
#  'southbayhikes/bigbasin/waterfallloop.html',
#  'northbayhikes/bothin.html',
#  'southbayhikes/fallcreek.html',
#  'southbayhikes/ebcp.html',
#  'northbayhikes/lucasvalley.html',
#  'southbayhikes/smcp.html',
#  'southbayhikes/lochlomond.html',
#  'northbayhikes/indiantree.html',
#  'northbayhikes/shiloh.html',
#  'northbayhikes/sptbarnabe.html',
#  'eastbayhikes/bdm.html',
#  'eastbayhikes/losvaqueros.html',
#  'southbayhikes/ranchoblack.html',
#  'eastbayhikes/bcbriones.html',
#  'eastbayhikes/kengrove.html',
#  'northbayhikes/ragle.html',
#  'northbayhikes/blithe.html',
#  'eastbayhikes/morgan.html',
#  'southbayhikes/pulgas.html',
#  'northbayhikes/altobowl.html',
#  'eastbayhikes/morgan.html',
#  'northbayhikes/gerbode.html',
#  'northbayhikes/bodegahead.html',
#  'southbayhikes/sanbrunoaccess.html',
#  'southbayhikes/sanbrunobog.html',
#  'northbayhikes/fivebrooks.html',
#  'northbayhikes/mountainhome.html',
#  'southbayhikes/purisimabald.html',
#  'northbayhikes/white.html',
#  'southbayhikes/portola.html',
#  'eastbayhikes/bcbriones.html',
#  'eastbayhikes/diablofoothills.html',
#  'southbayhikes/sanpedro.html',
#  'eastbayhikes/bortmeadow.html',
#  'northbayhikes/deerpark.html',
#  'southbayhikes/juniperoserra.html',
#  'northbayhikes/skylinewild.html',
#  'southbayhikes/hiddenvilla.html',
#  'northbayhikes/burdell.html',
#  'northbayhikes/invalley.html',
#  'eastbayhikes/carquinez.html',
#  'eastbayhikes/quarrylakes.html',
#  'northbayhikes/mountainhome.html',
#  'southbayhikes/grant.html',
#  'eastbayhikes/losvaqueros.html',
#  'southbayhikes/monte.html',
#  'eastbayhikes/sunol.html',
#  'eastbayhikes/mdsp/donnercanyon.html',
#  'eastbayhikes/carquinezwest.html',
#  'northbayhikes/cascade.html',
#  'northbayhikes/cascade.html',
#  'southbayhikes/almadenquicksilver.html',
#  'southbayhikes/castlerock.html',
#  'northbayhikes/cataractfalls.html',
#  'northbayhikes/rockspring.html',
#  'eastbayhikes/sunol.html',
#  'northbayhikes/tlsh.html',
#  'southbayhikes/ranchoduveneck.html',
#  'eastbayhikes/bdm.html',
#  'eastbayhikes/joaquinmiller.html',
#  'northbayhikes/skylinewild.html',
#  'southbayhikes/usccp.html',
#  'southbayhikes/huddartchick.html',
#  'northbayhikes/pv.html',
#  'northbayhikes/chimneyrock.html',
#  'eastbayhikes/coyotehills.html',
#  'southbayhikes/almadenquicksilver.html',
#  'northbayhikes/kingmtn.html',
#  'northbayhikes/prbv.html',
#  'northbayhikes/palomarin.html',
#  'northbayhikes/muirbeach.html',
#  'northbayhikes/muirwoodsroad.html',
#  'sfhikes/landsend.html',
#  'northbayhikes/rodeobeach.html',
#  'northbayhikes/burdell.html',
#  'northbayhikes/annadel/annadel2.html',
#  'northbayhikes/giacomini.html',
#  'eastbayhikes/ccct.html',
#  'eastbayhikes/pointpinole.html',
#  'southbayhikes/fremontolder.html',
#  'southbayhikes/pulgas.html',
#  'southbayhikes/henrycoe/headquarters.html',
#  'northbayhikes/bothenapa.htm',
#  'southbayhikes/santateresa.html',
#  'northbayhikes/muirbeach.html',
#  'southbayhikes/stevenscreek.html',
#  'eastbayhikes/morgan.html',
#  'southbayhikes/purisimahiggins.html',
#  'southbayhikes/coal.html',
#  'northbayhikes/crane.html',
#  'southbayhikes/montalvo.html',
#  'southbayhikes/fremontolder.html',
#  'northbayhikes/shiloh.html',
#  'eastbayhikes/millerknox.html',
#  'northbayhikes/sptbarnabe.html',
#  'southbayhikes/huddartdean.html',
#  'southbayhikes/phleger.html',
#  'southbayhikes/pwt.html',
#  'eastbayhikes/lastrampas.html',
#  'eastbayhikes/tilden.html',
#  'eastbayhikes/mdsp/diablocurry.html',
#  'southbayhikes/sanbrunosummit.html',
#  'northbayhikes/baltcanyon.html',
#  'southbayhikes/juniperoserra.html',
#  'southbayhikes/huddartdean.html',
#  'northbayhikes/indiantree.html',
#  'northbayhikes/burdell.html',
#  'northbayhikes/indiantree.html',
#  'northbayhikes/deerisland.html',
#  'northbayhikes/deerpark.html',
#  'northbayhikes/muirwoodsroad.html',
#  'northbayhikes/deerpark.html',
#  'northbayhikes/westwoodhills.html',
#  'northbayhikes/sptdevil.html',
#  'northbayhikes/stinson.html',
#  'northbayhikes/armstrong.html',
#  'northbayhikes/little.html',
#  'eastbayhikes/mdsp/donnercanyon.html',
#  'southbayhikes/bigbasin/waterfallloop.html',
#  'eastbayhikes/garin.html',
#  'northbayhikes/alstonpark.html',
#  'eastbayhikes/coyotehills.html',
#  'eastbayhikes/delvalle.html',
#  'eastbayhikes/mdsp/mcep.html',
#  'northbayhikes/ignacio.html',
#  'eastbayhikes/missionpeak.html',
#  'northbayhikes/armstrong.html',
#  'eastbayhikes/redwood.html',
#  'eastbayhikes/delvalle.html',
#  'northbayhikes/pantoll.html',
#  'southbayhikes/ebcp.html',
#  'sfhikes/inspoint.html',
#  'southbayhikes/ecdmsp.html',
#  'eastbayhikes/lastrampas.html',
#  'southbayhikes/almadenquicksilver.html',
#  'northbayhikes/caminoalto.html',
#  'northbayhikes/estero.html',
#  'northbayhikes/muddy.html',
#  'southbayhikes/sanbrunosummit.html',
#  'sfhikes/sutro.html',
#  'southbayhikes/fallcreek.html',
#  'eastbayhikes/mdsp/donnercanyon.html',
#  'northbayhikes/mountainhome.html',
#  'northbayhikes/crane.html',
#  'southbayhikes/calero.html',
#  'southbayhikes/ecdmsp.html',
#  'southbayhikes/elcortemadera.html',
#  'eastbayhikes/mdsp/diablosummit.html',
#  'eastbayhikes/sunol.html',
#  'southbayhikes/henrycoe/headquarters.html',
#  'eastbayhikes/diablofoothills.html',
#  'southbayhikes/stileranch.html',
#  'southbayhikes/lostrancos.html',
#  'eastbayhikes/carquinez.html',
#  'southbayhikes/arastradero.html',
#  'southbayhikes/lochlomond.html',
#  'northbayhikes/austincreek.html',
#  'southbayhikes/lochlomond.html',
#  'northbayhikes/lomaalta.html',
#  'northbayhikes/muddy.html',
#  'sfhikes/crissy.html',
#  'eastbayhikes/bortmeadow.html',
#  'southbayhikes/purisimabald.html',
#  'southbayhikes/hiddenvilla.html',
#  'eastbayhikes/bortmeadow.html',
#  'northbayhikes/sugarloaf.html',
#  'southbayhikes/mcneeranch.html',
#  'eastbayhikes/bishop.html',
#  'northbayhikes/muirbeach.html',
#  'northbayhikes/audubon.html',
#  'northbayhikes/lomaalta.html',
#  'southbayhikes/grant.html',
#  'southbayhikes/whsrhg.html',
#  'eastbayhikes/roundvalley.html',
#  'southbayhikes/purisimahiggins.html',
#  'southbayhikes/pulgas.html',
#  'southbayhikes/fremontolder.html',
#  'southbayhikes/sanpedrohazel.html',
#  'northbayhikes/muirwoodsroad.html',
#  'northbayhikes/osh.html',
#  'southbayhikes/smcp.html',
#  'eastbayhikes/delvalle.html',
#  'eastbayhikes/delvalle.html',
#  'northbayhikes/phoenixlake.html',
#  'southbayhikes/santateresa.html',
#  'eastbayhikes/missionpeak.html',
#  'eastbayhikes/hiddenbrooke.html',
#  'northbayhikes/rockspring.html',
#  'southbayhikes/rancho.html',
#  'eastbayhikes/garin.html',
#  'southbayhikes/fallcreek.html',
#  'eastbayhikes/sunol.html',
#  'northbayhikes/cascade.html',
#  'southbayhikes/lochlomond.html',
#  'southbayhikes/soquel.html',
#  'northbayhikes/invalley.html',
#  'northbayhikes/ragle.html',
#  'sfhikes/sutro.html',
#  'southbayhikes/henrycoe/headquarters.html',
#  'northbayhikes/blithe.html',
#  'northbayhikes/blithe.html',
#  'eastbayhikes/missionpeak.html',
#  'northbayhikes/altobowl.html',
#  'northbayhikes/prsky.html',
#  'northbayhikes/blithe.html',
#  'southbayhikes/hiddenvilla.html',
#  'southbayhikes/grant.html',
#  'eastbayhikes/huckleberry.htm',
#  'southbayhikes/henrycoe/coehh.html',
#  'southbayhikes/monte.html',
#  'eastbayhikes/sunol.html',
#  'northbayhikes/indiantree.html',
#  'northbayhikes/invalley.html',
#  'southbayhikes/skyline1.html',
#  'northbayhikes/tlshdnorth.html',
#  'southbayhikes/portola.html',
#  'eastbayhikes/bortmeadow.html',
#  'northbayhikes/tomales.html',
#  'eastbayhikes/wanda.html',
#  'northbayhikes/tomales.html',
#  'southbayhikes/stjosephs.htm',
#  'southbayhikes/arastradero.html',
#  'northbayhikes/deerpark.html',
#  'eastbayhikes/kengrove.html',
#  'northbayhikes/bontempe.html',
#  'northbayhikes/rockspring.html',
#  'northbayhikes/kingmtn.html',
#  'eastbayhikes/mdsp/diablocurry.html',
#  'northbayhikes/sonomabeach.html',
#  'eastbayhikes/briones.html',
#  'northbayhikes/skyoaks.html',
#  'northbayhikes/skylinewild.html',
#  'northbayhikes/jacklondon.html',
#  'northbayhikes/annadel/annadel.html',
#  'northbayhikes/jacklondon.html',
#  'eastbayhikes/lafres.html',
#  'northbayhikes/skyoaks.html',
#  'southbayhikes/larrylane.html',
#  'eastbayhikes/kengrove.html',
#  'eastbayhikes/leona.html',
#  'northbayhikes/pv.html',
#  'northbayhikes/little.html',
#  'southbayhikes/juniperoserra.html',
#  'northbayhikes/annadel/annadel.html',
#  'sfhikes/loboscreek.html',
#  'southbayhikes/lochlomond.html',
#  'southbayhikes/lochlomond.html',
#  'southbayhikes/longridge.html',
#  'southbayhikes/longridge.html',
#  'southbayhikes/stevenscreek.html',
#  'southbayhikes/montalvo.html',
#  'eastbayhikes/tilden.html',
#  'southbayhikes/madonna.html',
#  'northbayhikes/olompali.html',
#  'southbayhikes/alamitoscreek.html',
#  'southbayhikes/calero.html',
#  'eastbayhikes/losvaqueros.html',
#  'southbayhikes/lostrancos.html',
#  'northbayhikes/mountainhome.html',
#  'southbayhikes/windy.html',
#  'southbayhikes/whsrhg.html',
#  'sfhikes/inspoint.html',
#  'northbayhikes/sugarloaf.html',
#  'eastbayhikes/bdm.html',
#  'southbayhikes/rancho.html',
#  'eastbayhikes/kengrove.html',
#  'northbayhikes/lucasvalley.html',
#  'northbayhikes/tlshdnorth.html',
#  'northbayhikes/crane.html',
#  'northbayhikes/skyoaks.html',
#  'southbayhikes/wunderlich.html',
#  'eastbayhikes/bdm.html',
#  'eastbayhikes/sobrante.html',
#  'southbayhikes/henrycoe/headquarters.html',
#  'eastbayhikes/sobrante.html',
#  'southbayhikes/stjosephs.htm',
#  'southbayhikes/baylands.html',
#  'eastbayhikes/pointpinole.html',
#  'northbayhikes/marshall.html',
#  'eastbayhikes/mdsp/diablosummit.html',
#  'northbayhikes/stinson.html',
#  'southbayhikes/coal.html',
#  'northbayhikes/sugarloaf.html',
#  'eastbayhikes/waterbird.html',
#  'southbayhikes/arastradero.html',
#  'eastbayhikes/mdsp/donnercanyon.html',
#  'eastbayhikes/mdsp/mcep.html',
#  'southbayhikes/madonna.html',
#  'southbayhikes/elcortemadera.html',
#  'eastbayhikes/wildcatcanyon.html',
#  'northbayhikes/burdell.html',
#  'northbayhikes/burdell.html',
#  'northbayhikes/caminoalto.html',
#  'eastbayhikes/mdsp/donnercanyon.html',
#  'southbayhikes/mills.html',
#  'southbayhikes/russianridge.html',
#  'southbayhikes/almadenquicksilver.html',
#  'southbayhikes/santateresa.html',
#  'southbayhikes/phleger.html',
#  'eastbayhikes/mdsp/mcep.html',
#  'eastbayhikes/mdsp/mcep.html',
#  'northbayhikes/rodeobeach.html',
#  'eastbayhikes/roundvalley.html',
#  'northbayhikes/tenvalley.html',
#  'southbayhikes/sanpedro.html',
#  'southbayhikes/ranchoblack.html',
#  'northbayhikes/ignacio.html',
#  'southbayhikes/henrycoe/headquarters.html',
#  'eastbayhikes/bcbriones.html',
#  'northbayhikes/jacklondon.html',
#  'southbayhikes/memorial.html',
#  'southbayhikes/memorial.html',
#  'northbayhikes/rlssp.html',
#  'northbayhikes/prsky.html',
#  'northbayhikes/muddy.html',
#  'northbayhikes/muddy.html',
#  'eastbayhikes/coyotehills.html',
#  'eastbayhikes/rockville.html',
#  'eastbayhikes/dewf.html',
#  'eastbayhikes/garin.html',
#  'sfhikes/sutro.html',
#  'eastbayhikes/tilden.html',
#  'northbayhikes/annadel/annadel.html',
#  'southbayhikes/montalvo.html',
#  'southbayhikes/mcneeranch.html',
#  'sfhikes/sutro.html',
#  'northbayhikes/angelisland.html',
#  'eastbayhikes/bdm.html',
#  'southbayhikes/stjosephs.htm',
#  'northbayhikes/chinacamp.html',
#  'eastbayhikes/pleasanton.html',
#  'northbayhikes/foothill.html',
#  'northbayhikes/carsonfalls.html',
#  'northbayhikes/mountainhome.html',
#  'eastbayhikes/bcbriones.html',
#  'eastbayhikes/millerknox.html',
#  'eastbayhikes/quarrylakes.html',
#  'southbayhikes/sanbrunoaccess.html',
#  'southbayhikes/sanbrunosaddle.html',
#  'southbayhikes/portola.html',
#  'eastbayhikes/garin.html',
#  'northbayhikes/tenvalley.html',
#  'northbayhikes/pantoll.html',
#  'southbayhikes/mcneeranch.html',
#  'northbayhikes/burdell.html',
#  'northbayhikes/blithe.html',
#  'northbayhikes/lomaalta.html',
#  'southbayhikes/monte.html',
#  'southbayhikes/cmr.html',
#  'northbayhikes/pantoll.html',
#  'northbayhikes/fivebrooks.html',
#  'eastbayhikes/pleasanton.html',
#  'southbayhikes/butano.html',
#  'southbayhikes/picchetti.html',
#  'northbayhikes/alstonpark.html',
#  'northbayhikes/annadel/annadel2.html',
#  'northbayhikes/phoenixlake.html',
#  'eastbayhikes/pointpinole.html',
#  'eastbayhikes/joaquinmiller.html',
#  'northbayhikes/hputnam.html',
#  'northbayhikes/mountainhome.html',
#  'northbayhikes/chinacamp.html',
#  'eastbayhikes/missionpeak.html',
#  'eastbayhikes/missionpeak.html',
#  'southbayhikes/calero.html',
#  'southbayhikes/longridge.html',
#  'eastbayhikes/redwood.html',
#  'northbayhikes/phoenixlake.html',
#  'northbayhikes/ringmountain.html',
#  'northbayhikes/skyoaks.html',
#  'southbayhikes/bigbasin1.html',
#  'northbayhikes/carsonfalls.html',
#  'southbayhikes/bigbasin1.html',
#  'southbayhikes/henrycowell.html',
#  'northbayhikes/rush.html',
#  'northbayhikes/armstrong.html',
#  'eastbayhikes/garin.html',
#  'southbayhikes/henrycowell.html',
#  'southbayhikes/hiddenvilla.html',
#  'northbayhikes/eastpeak.html',
#  'southbayhikes/sanpedrohazel.html',
#  'eastbayhikes/pointpinole.html',
#  'southbayhikes/pulgas.html',
#  'northbayhikes/hputnam.html',
#  'southbayhikes/memorial.html',
#  'southbayhikes/portola.html',
#  'southbayhikes/anonuevo2.html',
#  'southbayhikes/skylinealpine.html',
#  'northbayhikes/shiloh.html',
#  'southbayhikes/henrycoe/headquarters.html',
#  'eastbayhikes/redwood.html',
#  'southbayhikes/almadenquicksilver.html',
#  'northbayhikes/alstonpark.html',
#  'northbayhikes/skyoaks.html',
#  'southbayhikes/purisimahiggins.html',
#  'southbayhikes/juniperoserra.html',
#  'eastbayhikes/carquinez.html',
#  'southbayhikes/burleigh.html',
#  'southbayhikes/almadenquicksilver.html',
#  'eastbayhikes/coyotehills.html',
#  'eastbayhikes/bishop.html',
#  'northbayhikes/muirwoodsroad.html',
#  'southbayhikes/henrycowell.html',
#  'southbayhikes/bigbasin1.html',
#  'northbayhikes/bothenapa.htm',
#  'southbayhikes/purisimaredwood.html',
#  'southbayhikes/wunderlich.html',
#  'northbayhikes/ringmountain.html',
#  'southbayhikes/baylands.html',
#  'southbayhikes/ecdmsp.html',
#  'northbayhikes/little.html',
#  'southbayhikes/ranchoblack.html',
#  'southbayhikes/ranchoduveneck.html',
#  'southbayhikes/phleger.html',
#  'eastbayhikes/limeridge.html',
#  'northbayhikes/pantoll.html',
#  'northbayhikes/sptbarnabe.html',
#  'southbayhikes/henrycowell.html',
#  'eastbayhikes/bdm.html',
#  'southbayhikes/castlerock.html',
#  'southbayhikes/fallcreek.html',
#  'northbayhikes/fivebrooks.html',
#  'northbayhikes/hputnam.html',
#  'southbayhikes/madonna.html',
#  'southbayhikes/russianridge.html',
#  'northbayhikes/shiloh.html',
#  'southbayhikes/skyline1.html',
#  'eastbayhikes/delvalle.html',
#  'eastbayhikes/pleasanton.html',
#  'northbayhikes/tlsh.html',
#  'eastbayhikes/lafres.html',
#  'southbayhikes/henrycowell.html',
#  'northbayhikes/ringmountain.html',
#  'northbayhikes/bothenapa.htm',
#  'southbayhikes/henrycowell.html',
#  'eastbayhikes/rockville.html',
#  'northbayhikes/rockspring.html',
#  'northbayhikes/pantoll.html',
#  'northbayhikes/bontempe.html',
#  'eastbayhikes/lastrampas.html',
#  'southbayhikes/santateresa.html',
#  'northbayhikes/westwoodhills.html',
#  'northbayhikes/gerbode.html',
#  'northbayhikes/gerbode.html',
#  'northbayhikes/annadel/annadel.html',
#  'northbayhikes/roys.html',
#  'eastbayhikes/sibley.html',
#  'northbayhikes/rush.html',
#  'southbayhikes/sanbrunosaddle.html',
#  'southbayhikes/lostrancos.html',
#  'northbayhikes/burdell.html',
#  'northbayhikes/burdell.html',
#  'southbayhikes/baylands.html',
#  'northbayhikes/giacomini.html',
#  'northbayhikes/burdell.html',
#  'eastbayhikes/wildcatcanyon.html',
#  'northbayhikes/sanpedro.html',
#  'northbayhikes/little.html',
#  'sfhikes/funston.html',
#  'southbayhikes/almadenquicksilver.html',
#  'southbayhikes/castlerock.html',
#  'southbayhikes/whsrhg.html',
#  'southbayhikes/windysausal.html',
#  'northbayhikes/hputnam.html',
#  'southbayhikes/sawyercamp.html',
#  'southbayhikes/pescaderomarsh.html',
#  'eastbayhikes/joaquinmiller.html',
#  'southbayhikes/portola.html',
#  'southbayhikes/edgewood.html',
#  'southbayhikes/edgewood.html',
#  'southbayhikes/fremontolder.html',
#  'northbayhikes/phoenixlake.html',
#  'northbayhikes/white.html',
#  'northbayhikes/chinacamp.html',
#  'southbayhikes/elcortemadera.html',
#  'northbayhikes/rockspring.html',
#  'eastbayhikes/joaquinmiller.html',
#  'northbayhikes/skyoaks.html',
#  'northbayhikes/prsky.html',
#  'southbayhikes/sanborn.html',
#  'northbayhikes/skylinewild.html',
#  'southbayhikes/bbrdo.html',
#  'southbayhikes/bigbasin/waterfallloop.html',
#  'northbayhikes/tlshdnorth.html',
#  'northbayhikes/lomaalta.html',
#  'southbayhikes/sweeney.html',
#  'northbayhikes/tlsh.html',
#  'northbayhikes/tlsh.html',
#  'eastbayhikes/coyotehills.html',
#  'eastbayhikes/sobrante.html',
#  'northbayhikes/jacklondon.html',
#  'northbayhikes/jacklondon.html',
#  'northbayhikes/hputnam.html',
#  'southbayhikes/montalvo.html',
#  'eastbayhikes/rushranch.html',
#  'sfhikes/sutro.html',
#  'southbayhikes/whsrhg.html',
#  'southbayhikes/windysausal.html',
#  'northbayhikes/little.html',
#  'northbayhikes/stinson.html',
#  'northbayhikes/annadel/annadel.html',
#  'southbayhikes/monte.html',
#  'southbayhikes/stevenscreek.html',
#  'northbayhikes/rlssp.html',
#  'northbayhikes/fivebrooks.html',
#  'eastbayhikes/bdm.html',
#  'southbayhikes/stileranch.html',
#  'northbayhikes/bontempe.html',
#  'eastbayhikes/morgan.html',
#  'eastbayhikes/diablofoothills.html',
#  'eastbayhikes/redwood.html',
#  'eastbayhikes/bishop.html',
#  'southbayhikes/sanbrunosummit.html',
#  'southbayhikes/skyline1.html',
#  'northbayhikes/estero.html',
#  'northbayhikes/angelisland.html',
#  'southbayhikes/bigbasin/waterfallloop.html',
#  'eastbayhikes/joaquinmiller.html',
#  'southbayhikes/sweeney.html',
#  'southbayhikes/edgewood.html',
#  'southbayhikes/usccp.html',
#  'southbayhikes/ecdmsp.html',
#  'southbayhikes/elcortemadera.html',
#  'northbayhikes/tlshdnorth.html',
#  'northbayhikes/staffordlk.html',
#  'eastbayhikes/pleasanton.html',
#  'northbayhikes/thorner.html',
#  'northbayhikes/foothill.html',
#  'northbayhikes/maxwell.html',
#  'eastbayhikes/dewf.html',
#  'northbayhikes/tlsh.html',
#  'northbayhikes/tomalespt.html',
#  'southbayhikes/smcp.html',
#  'southbayhikes/cmr.html',
#  'northbayhikes/jacklondon.html',
#  'eastbayhikes/redwood.html',
#  'northbayhikes/mountainhome.html',
#  'northbayhikes/mountainhome.html',
#  'southbayhikes/fallcreek.html',
#  'southbayhikes/wilder.html',
#  'northbayhikes/indiantree.html',
#  'eastbayhikes/kengrove.html',
#  'northbayhikes/caminoalto.html',
#  'eastbayhikes/lastrampas.html',
#  'southbayhikes/rancho.html',
#  'southbayhikes/calero.html',
#  'northbayhikes/alstonpark.html',
#  'eastbayhikes/losvaqueros.html',
#  'southbayhikes/sanpedrovvl.html',
#  'northbayhikes/westwoodhills.html',
#  'northbayhikes/maxwell.html',
#  'northbayhikes/little.html',
#  'northbayhikes/eastpeak.html',
#  'southbayhikes/stevenscreek.html',
#  'eastbayhikes/sibley.html',
#  'eastbayhikes/morgan.html',
#  'northbayhikes/annadel/annadel.html',
#  'southbayhikes/uvas.html',
#  'southbayhikes/sanpedrohazel.html',
#  'southbayhikes/sanpedrovvl.html',
#  'eastbayhikes/millerknox.html',
#  'eastbayhikes/quarrylakes.html',
#  'northbayhikes/foothill.html',
#  'northbayhikes/white.html',
#  'southbayhikes/monte.html',
#  'southbayhikes/anonuevo.html',
#  'southbayhikes/wilburswatch.html',
#  'southbayhikes/rancho.html',
#  'eastbayhikes/wildcatcanyon.html',
#  'eastbayhikes/tilden.html',
#  'northbayhikes/invalley.html',
#  'southbayhikes/wilder.html',
#  'northbayhikes/tubbs.html',
#  'northbayhikes/rodeobeach.html',
#  'eastbayhikes/quarrylakes.html',
#  'eastbayhikes/pleasanton.html',
#  'northbayhikes/sanpedro.html',
#  'southbayhikes/arastradero.html',
#  'southbayhikes/sierraazul/sierraazul2.html',
#  'northbayhikes/deerpark.html',
#  'southbayhikes/grant.html',
#  'northbayhikes/phoenixlake.html',
#  'northbayhikes/deerpark.html',
#  'northbayhikes/prsky.html',
#  'southbayhikes/wilder.html',
#  'southbayhikes/picchetti.html']

# %% [markdown]
# ### Process Hike

# %%
def construct_url(hikepath, content='sidebar.html'):
    url_part_1 = hikepath[:hikepath.find('/')]
    url_part_2 = hikepath[hikepath.find('/')+1:hikepath.find('.')]
    url_part_3 = content
    return '/'.join([BASE_URL, url_part_1, url_part_2, url_part_3])


def fetch(item):
    print('fetching', item)
    response = requests.get(item)
    if response.status_code == 200:
        return response


def gen_filename(url_path):
    step_1 = url_path[url_path.find('.com/') + 5:]
    return step_1.replace('/', '_')


def filename_to_path(filename):
    step_1 = filename.replace('_sidebar', '')
    return step_1.replace('_', '/')


def find_by_text(soup, item):
    try:
        return soup.find(lambda x: x.text == item).nextSibling.nextSibling.nextSibling.strip()
    except Exception:
        pass

    
def get_this_childs_text(bs):
    text = ''
    for child in bs:
        if isinstance(child, Tag):
            text += ' ' + child.text
    
    return text
    

print(filename_to_path('northbayhikes_abbottslagoon_sidebar.html'))
# Out:
# northbayhikes/abbottslagoon.html

# %%
logger = []
for trail in trails_paths:
    trail_url = construct_url(trail)
    try:
        res = fetch(trail_url)
        with open('raw/trails/' + gen_filename(trail_url), 'wb') as outfile:
            logger.append(trail_url)
            outfile.write(res.content)
    except Exception as e:
        print(e)
        
    time.sleep(10)
# Out:
# fetching http://bahiker.com/northbayhikes/abbottslagoon/sidebar.html
# fetching http://bahiker.com/southbayhikes/arastradero/sidebar.html
# fetching http://bahiker.com/southbayhikes/baylands/sidebar.html
# fetching http://bahiker.com/southbayhikes/hiddenvilla/sidebar.html
# fetching http://bahiker.com/southbayhikes/wunderlich/sidebar.html
# fetching http://bahiker.com/eastbayhikes/coyotehills/sidebar.html
# fetching http://bahiker.com/eastbayhikes/quarrylakes/sidebar.html
# fetching http://bahiker.com/eastbayhikes/diablofoothills/sidebar.html
# fetching http://bahiker.com/southbayhikes/uvas/sidebar.html
# fetching http://bahiker.com/northbayhikes/invalley/sidebar.html
# fetching http://bahiker.com/southbayhikes/skylinealpine/sidebar.html
# fetching http://bahiker.com/southbayhikes/coal/sidebar.html
# fetching http://bahiker.com/southbayhikes/cmr/sidebar.html
# fetching http://bahiker.com/northbayhikes/foothill/sidebar.html
# fetching http://bahiker.com/northbayhikes/altobowl/sidebar.html
# fetching http://bahiker.com/southbayhikes/russianridge/sidebar.html
# fetching http://bahiker.com/southbayhikes/whsrhg/sidebar.html
# fetching http://bahiker.com/southbayhikes/anonuevo2/sidebar.html
# fetching http://bahiker.com/southbayhikes/butano/sidebar.html
# fetching http://bahiker.com/southbayhikes/elsereno/sidebar.html
# fetching http://bahiker.com/eastbayhikes/rockville/sidebar.html
# fetching http://bahiker.com/eastbayhikes/mlkshoreline/sidebar.html
# fetching http://bahiker.com/northbayhikes/hputnam/sidebar.html
# fetching http://bahiker.com/northbayhikes/austincreek/sidebar.html
# fetching http://bahiker.com/northbayhikes/rockspring/sidebar.html
# fetching http://bahiker.com/northbayhikes/deerpark/sidebar.html
# fetching http://bahiker.com/southbayhikes/purisimabald/sidebar.html
# fetching http://bahiker.com/southbayhikes/sierraazul/sierraazul/sidebar.html
# fetching http://bahiker.com/northbayhikes/sugarloaf/sidebar.html
# fetching http://bahiker.com/northbayhikes/sptbarnabe/sidebar.html
# fetching http://bahiker.com/northbayhikes/sugarloaf/sidebar.html
# fetching http://bahiker.com/sfhikes/funston/sidebar.html
# fetching http://bahiker.com/eastbayhikes/rockville/sidebar.html
# fetching http://bahiker.com/northbayhikes/indiantree/sidebar.html
# fetching http://bahiker.com/northbayhikes/skylinewild/sidebar.html
# fetching http://bahiker.com/eastbayhikes/carquinez/sidebar.html
# fetching http://bahiker.com/northbayhikes/burdell/sidebar.html
# fetching http://bahiker.com
#  'raw/trails/eastbayhikes_bdm_sidebar.html',
#  'raw/trails/eastbayhikes_bishop_sidebar.html',
#  'raw/trails/eastbayhikes_bortmeadow_sidebar.html',
#  'raw/trails/eastbayhikes_briones_sidebar.html',
#  'raw/trails/eastbayhikes_carquinez_sidebar.html',
#  'raw/trails/eastbayhikes_carquinezwest_sidebar.html',
#  'raw/trails/eastbayhikes_ccct_sidebar.html',
#  'raw/trails/eastbayhikes_coyotehills_sidebar.html',
#  'raw/trails/eastbayhikes_delvalle_sidebar.html',
#  'raw/trails/eastbayhikes_dewf_sidebar.html',
#  'raw/trails/eastbayhikes_diablofoothills_sidebar.html',
#  'raw/trails/eastbayhikes_garin_sidebar.html',
#  'raw/trails/eastbayhikes_hiddenbrooke_sidebar.html',
#  'raw/trails/eastbayhikes_hrs_sidebar.html',
#  'raw/trails/eastbayhikes_huckleberry_sidebar.html',
#  'raw/trails/eastbayhikes_joaquinmiller_sidebar.html',
#  'raw/trails/eastbayhikes_kengrove_sidebar.html',
#  'raw/trails/eastbayhikes_lafres_sidebar.html',
#  'raw/trails/eastbayhikes_lastrampas_sidebar.html',
#  'raw/trails/eastbayhikes_leona_sidebar.html',
#  'raw/trails/eastbayhikes_limeridge_sidebar.html',
#  'raw/trails/eastbayhikes_losvaqueros_sidebar.html',
#  'raw/trails/eastbayhikes_mdsp_diablocurry_sidebar.html',
#  'raw/trails/eastbayhikes_mdsp_diablosummit_sidebar.html',
#  'raw/trails/eastbayhikes_mdsp_donnercanyon_sidebar.html',
#  'raw/trails/eastbayhikes_mdsp_mcep_sidebar.html',
#  'raw/trails/eastbayhikes_millerknox_sidebar.html',
#  'raw/trails/eastbayhikes_missionpeak_sidebar.html',
#  'raw/trails/eastbayhikes_mlkshoreline_sidebar.html',
#  'raw/trails/eastbayhikes_morgan_sidebar.html',
#  'raw/trails/eastbayhikes_nwaterfront_sidebar.html',
#  'raw/trails/eastbayhikes_oyster_sidebar.html',
#  'raw/trails/eastbayhikes_pleasanton_sidebar.html',
#  'raw/trails/eastbayhikes_pointpinole_sidebar.html',
#  'raw/trails/eastbayhikes_ptisabel_sidebar.html',
#  'raw/trails/eastbayhikes_quarrylakes_sidebar.html',
#  'raw/trails/eastbayhikes_redwood_sidebar.html',
#  'raw/trails/eastbayhikes_rockville_sidebar.html',
#  'raw/trails/eastbayhikes_roundvalley_sidebar.html',
#  'raw/trails/eastbayhikes_rushranch_sidebar.html',
#  'raw/trails/eastbayhikes_sibley_sidebar.html',
#  'raw/trails/eastbayhikes_sobrante_sidebar.html',
#  'raw/trails/eastbayhikes_sunol_sidebar.html',
#  'raw/trails/eastbayhikes_tilden_sidebar.html',
#  'raw/trails/eastbayhikes_wanda_sidebar.html',
#  'raw/trails/eastbayhikes_waterbird_sidebar.html',
#  'raw/trails/eastbayhikes_wildcatcanyon_sidebar.html',
#  'raw/trails/northbayhikes_abbottslagoon_sidebar.html',
#  'raw/trails/northbayhikes_alstonpark_sidebar.html',
#  'raw/trails/northbayhikes_altobowl_sidebar.html',
#  'raw/trails/northbayhikes_angelisland_sidebar.html',
#  'raw/trails/northbayhikes_annadel_annadel2_sidebar.html',
#  'raw/trails/northbayhikes_annadel_annadel_sidebar.html',
#  'raw/trails/northbayhikes_armstrong_sidebar.html',
#  'raw/trails/northbayhikes_audubon_sidebar.html',
#  'raw/trails/northbayhikes_austincreek_sidebar.html',
#  'raw/trails/northbayhikes_baltcanyon_sidebar.html',
#  'raw/trails/northbayhikes_barbier_sidebar.html',
#  'raw/trails/northbayhikes_blithe_sidebar.html',
#  'raw/trails/northbayhikes_bodegahead_sidebar.html',
#  'raw/trails/northbayhikes_bontempe_sidebar.html',
#  'raw/trails/northbayhikes_bothenapa_sidebar.html',
#  'raw/trails/northbayhikes_bothin_sidebar.html',
#  'raw/trails/northbayhikes_burdell_sidebar.html',
#  'raw/trails/northbayhikes_caminoalto_sidebar.html',
#  'raw/trails/northbayhikes_carsonfalls_sidebar.html',
#  'raw/trails/northbayhikes_cascade_sidebar.html',
#  'raw/trails/northbayhikes_cataractfalls_sidebar.html',
#  'raw/trails/northbayhikes_chimneyrock_sidebar.html',
#  'raw/trails/northbayhikes_chinacamp_sidebar.html',
#  'raw/trails/northbayhikes_crane_sidebar.html',
#  'raw/trails/northbayhikes_deerisland_sidebar.html',
#  'raw/trails/northbayhikes_deerpark_sidebar.html',
#  'raw/trails/northbayhikes_eastpeak_sidebar.html',
#  'raw/trails/northbayhikes_estero_sidebar.html',
#  'raw/trails/northbayhikes_fivebrooks_sidebar.html',
#  'raw/trails/northbayhikes_foothill_sidebar.html',
#  'raw/trails/northbayhikes_gerbode_sidebar.html',
#  'raw/trails/northbayhikes_giacomini_sidebar.html',
#  'raw/trails/northbayhikes_hputnam_sidebar.html',
#  'raw/trails/northbayhikes_ignacio_sidebar.html',
#  'raw/trails/northbayhikes_indiantree_sidebar.html',
#  'raw/trails/northbayhikes_invalley_sidebar.html',
#  'raw/trails/northbayhikes_jacklondon_sidebar.html',
#  'raw/trails/northbayhikes_kingmtn_sidebar.html',
#  'raw/trails/northbayhikes_little_sidebar.html',
#  'raw/trails/northbayhikes_lomaalta_sidebar.html',
#  'raw/trails/northbayhikes_lucasvalley_sidebar.html',
#  'raw/trails/northbayhikes_marshall_sidebar.html',
#  'raw/trails/northbayhikes_maxwell_sidebar.html',
#  'raw/trails/northbayhikes_mountainhome_sidebar.html',
#  'raw/trails/northbayhikes_muddy_sidebar.html',
#  'raw/trails/northbayhikes_muirbeach_sidebar.html',
#  'raw/trails/northbayhikes_muirwoodsroad_sidebar.html',
#  'raw/trails/northbayhikes_olompali_sidebar.html',
#  'raw/trails/northbayhikes_osh_sidebar.html',
#  'raw/trails/northbayhikes_palomarin_sidebar.html',
#  'raw/trails/northbayhikes_pantoll_sidebar.html',
#  'raw/trails/northbayhikes_phoenixlake_sidebar.html',
#  'raw/trails/northbayhikes_prbv_sidebar.html',
#  'raw/trails/northbayhikes_prsky_sidebar.html',
#  'raw/trails/northbayhikes_pv_sidebar.html',
#  'raw/trails/northbayhikes_ragle_sidebar.html',
#  'raw/trails/northbayhikes_ringmountain_sidebar.html',
#  'raw/trails/northbayhikes_rlssp_sidebar.html',
#  'raw/trails/northbayhikes_rockspring_sidebar.html',
#  'raw/trails/northbayhikes_rodeobeach_sidebar.html',
#  'raw/trails/northbayhikes_roys_sidebar.html',
#  'raw/trails/northbayhikes_rush_sidebar.html',
#  'raw/trails/northbayhikes_sanpedro_sidebar.html',
#  'raw/trails/northbayhikes_shiloh_sidebar.html',
#  'raw/trails/northbayhikes_skylinewild_sidebar.html',
#  'raw/trails/northbayhikes_skyoaks_sidebar.html',
#  'raw/trails/northbayhikes_skywalker_sidebar.html',
#  'raw/trails/northbayhikes_sonomabeach_sidebar.html',
#  'raw/trails/northbayhikes_sptbarnabe_sidebar.html',
#  'raw/trails/northbayhikes_sptdevil_sidebar.html',
#  'raw/trails/northbayhikes_staffordlk_sidebar.html',
#  'raw/trails/northbayhikes_stinson_sidebar.html',
#  'raw/trails/northbayhikes_sugarloaf_sidebar.html',
#  'raw/trails/northbayhikes_tenvalley_sidebar.html',
#  'raw/trails/northbayhikes_thorner_sidebar.html',
#  'raw/trails/northbayhikes_tlsh_sidebar.html',
#  'raw/trails/northbayhikes_tlshdnorth_sidebar.html',
#  'raw/trails/northbayhikes_tomales_sidebar.html',
#  'raw/trails/northbayhikes_tomalespt_sidebar.html',
#  'raw/trails/northbayhikes_tubbs_sidebar.html',
#  'raw/trails/northbayhikes_westwoodhills_sidebar.html',
#  'raw/trails/northbayhikes_white_sidebar.html',
#  'raw/trails/sfhikes_crissy_sidebar.html',
#  'raw/trails/sfhikes_funston_sidebar.html',
#  'raw/trails/sfhikes_inspoint_sidebar.html',
#  'raw/trails/sfhikes_landsend_sidebar.html',
#  'raw/trails/sfhikes_loboscreek_sidebar.html',
#  'raw/trails/sfhikes_sutro_sidebar.html',
#  'raw/trails/southbayhikes_alamitoscreek_sidebar.html',
#  'raw/trails/southbayhikes_almadenquicksilver_sidebar.html',
#  'raw/trails/southbayhikes_anonuevo2_sidebar.html',
#  'raw/trails/southbayhikes_anonuevo_sidebar.html',
#  'raw/trails/southbayhikes_arastradero_sidebar.html',
#  'raw/trails/southbayhikes_bair_sidebar.html',
#  'raw/trails/southbayhikes_baylands_sidebar.html',
#  'raw/trails/southbayhikes_bbrdo_sidebar.html',
#  'raw/trails/southbayhikes_bigbasin1_sidebar.html',
#  'raw/trails/southbayhikes_bigbasin_waterfallloop_sidebar.html',
#  'raw/trails/southbayhikes_burleigh_sidebar.html',
#  'raw/trails/southbayhikes_butano_sidebar.html',
#  'raw/trails/southbayhikes_calero_sidebar.html',
#  'raw/trails/southbayhikes_castlerock_sidebar.html',
#  'raw/trails/southbayhikes_cmr_sidebar.html',
#  'raw/trails/southbayhikes_coal_sidebar.html',
#  'raw/trails/southbayhikes_coyotepoint_sidebar.html',
#  'raw/trails/southbayhikes_ebcp_sidebar.html',
#  'raw/trails/southbayhikes_ecdmsp_sidebar.html',
#  'raw/trails/southbayhikes_edgewood_sidebar.html',
#  'raw/trails/southbayhikes_elcortemadera_sidebar.html',
#  'raw/trails/southbayhikes_elsereno_sidebar.html',
#  'raw/trails/southbayhikes_fallcreek_sidebar.html',
#  'raw/trails/southbayhikes_fremontolder_sidebar.html',
#  'raw/trails/southbayhikes_grant_sidebar.html',
#  'raw/trails/southbayhikes_henrycoe_coehh_sidebar.html',
#  'raw/trails/southbayhikes_henrycoe_headquarters_sidebar.html',
#  'raw/trails/southbayhikes_henrycowell_sidebar.html',
#  'raw/trails/southbayhikes_hiddenvilla_sidebar.html',
#  'raw/trails/southbayhikes_huddartchick_sidebar.html',
#  'raw/trails/southbayhikes_huddartdean_sidebar.html',
#  'raw/trails/southbayhikes_juniperoserra_sidebar.html',
#  'raw/trails/southbayhikes_larrylane_sidebar.html',
#  'raw/trails/southbayhikes_lochlomond_sidebar.html',
#  'raw/trails/southbayhikes_longridge_sidebar.html',
#  'raw/trails/southbayhikes_lostrancos_sidebar.html',
#  'raw/trails/southbayhikes_madonna_sidebar.html',
#  'raw/trails/southbayhikes_mcneeranch_sidebar.html',
#  'raw/trails/southbayhikes_memorial_sidebar.html',
#  'raw/trails/southbayhikes_mills_sidebar.html',
#  'raw/trails/southbayhikes_montalvo_sidebar.html',
#  'raw/trails/southbayhikes_monte_sidebar.html',
#  'raw/trails/southbayhikes_pescaderomarsh_sidebar.html',
#  'raw/trails/southbayhikes_phleger_sidebar.html',
#  'raw/trails/southbayhikes_picchetti_sidebar.html',
#  'raw/trails/southbayhikes_portola_sidebar.html',
#  'raw/trails/southbayhikes_pulgas_sidebar.html',
#  'raw/trails/southbayhikes_purisimabald_sidebar.html',
#  'raw/trails/southbayhikes_purisimahiggins_sidebar.html',
#  'raw/trails/southbayhikes_purisimanorth_sidebar.html',
#  'raw/trails/southbayhikes_purisimaredwood_sidebar.html',
#  'raw/trails/southbayhikes_pwt_sidebar.html',
#  'raw/trails/southbayhikes_rancho_sidebar.html',
#  'raw/trails/southbayhikes_ranchoblack_sidebar.html',
#  'raw/trails/southbayhikes_ranchoduveneck_sidebar.html',
#  'raw/trails/southbayhikes_ravenswood_sidebar.html',
#  'raw/trails/southbayhikes_russianridge_sidebar.html',
#  'raw/trails/southbayhikes_sanborn_sidebar.html',
#  'raw/trails/southbayhikes_sanbrunoaccess_sidebar.html',
#  'raw/trails/southbayhikes_sanbrunobog_sidebar.html',
#  'raw/trails/southbayhikes_sanbrunosaddle_sidebar.html',
#  'raw/trails/southbayhikes_sanbrunosummit_sidebar.html',
#  'raw/trails/southbayhikes_sanpedro_sidebar.html',
#  'raw/trails/southbayhikes_sanpedrohazel_sidebar.html',
#  'raw/trails/southbayhikes_sanpedrovvl_sidebar.html',
#  'raw/trails/southbayhikes_santateresa_sidebar.html',
#  'raw/trails/southbayhikes_sawyercamp_sidebar.html',
#  'raw/trails/southbayhikes_shoreline_sidebar.html',
#  'raw/trails/southbayhikes_sierraazul_sierraazul2_sidebar.html',
#  'raw/trails/southbayhikes_sierraazul_sierraazul_sidebar.html',
#  'raw/trails/southbayhikes_skyline1_sidebar.html',
#  'raw/trails/southbayhikes_skylinealpine_sidebar.html',
#  'raw/trails/southbayhikes_smcp_sidebar.html',
#  'raw/trails/southbayhikes_soquel_sidebar.html',
#  'raw/trails/southbayhikes_stevenscreek_sidebar.html',
#  'raw/trails/southbayhikes_stileranch_sidebar.html',
#  'raw/trails/southbayhikes_stjosephs_sidebar.html',
#  'raw/trails/southbayhikes_sweeney_sidebar.html',
#  'raw/trails/southbayhikes_usccp_sidebar.html',
#  'raw/trails/southbayhikes_uvas_sidebar.html',
#  'raw/trails/southbayhikes_whsrhg_sidebar.html',
#  'raw/trails/southbayhikes_wilburswatch_sidebar.html',
#  'raw/trails/southbayhikes_wilder_sidebar.html',
#  'raw/trails/southbayhikes_windy_sidebar.html',
#  'raw/trails/southbayhikes_windysausal_sidebar.html',
#  'raw/trails/southbayhikes_wunderlich_sidebar.html']

# %%
FIELDS = ('exposure', 'trail surfaces',\
          'trail traffic', 'hiking time',\
          'season', 'gas, food, and lodging', 'rules',\
          'trailhead details', 'map choices',\
          'distance, category, and difficulty')
trail_info = []
for file_name in glob('raw/trails/*.html')[:1]:
    with open(file_name, 'rb') as trail:
        sidebar = BeautifulSoup(trail, 'lxml')
        row = {
            'uri': filename_to_path(file_name.replace('raw/trails/', '')),
        }
        for i in sidebar.findAll('i'):
            i.text.strip().lower()
            if i.text.strip().lower() in FIELDS:
                print([s for s in i.strings])
                try:
                    val = clean_text(i.nextSibling.nextSibling.nextSibling)
                except Exception:
                    val = ''
                row[i.text.strip().lower()] = val
        trail_info.append(row)
        
trail_info
# Out:
# ['Distance, category, and difficulty']
# ['Exposur', 'e']
# ['Exposur', 'e']
# ['Exposur', 'e']
# ['Exposur', 'e']
# ['\n', '\r\nTrail traffic']
# ['\n', '\r\nTrail traffic']
# ['\n', '\r\nTrail traffic']
# ['\n', '\r\nTrail traffic']
# ['\r\nTrail traffic']
# ['\n', '\r\nTrail surfaces']
# ['\n', '\r\nTrail surfaces']
# ['\n', '\r\nTrail surfaces']
# ['\n', '\r\nTrail surfaces']
# ['\n', '\r\nTrail surfaces']
# ['\n', '\r\nHiking time']
# ['\r\nHiking time']
# ['\r\nHiking time']
# ['\r\nHiking time']
# ['\r\nHiking time']
# ['\n', '\r\nSeason']
# ['\n', '\r\nSeason']
# ['\n', '\r\nSeason']
# ['\n', '\r\nSeason']
# ['\n', '\r\nSeason']
# ['Gas, food, and lodging']
# ['Trailhead details']
# ['Rules']
# [{'distance, category, and difficulty': 'This ',
#   'exposure': '',
#   'gas, food, and lodging': 'Pay phone, stores, gas, and restaurants back near CA 24 in Orinda. No individual camp sites in the park, although there is a group camp. Nearest campgrounds are in ',
#   'hiking time': '',
#   'rules': 'Most trails are multi-use. A few are open to equestrians and hikers only, and one trail is designated hiking only. Dogs are permitted. Park is open from 8 a.m. to 10 p.m.',
#   'season': '',
#   'trail surfaces': '',
#   'trail traffic': '',
#   'trailhead details': 'Parking fee of $5 charged when entrance kiosk is staffed. $2 dog fee. Lots of parking. Pit toilets on site, but no drinking water. Maps available at the information signboard near the start of the trail. There is no direct public transportation to this trailhead, but you can walk (or cycle) into the park from BART: visit ',
#   'uri': 'eastbayhikes/bcbriones.html'}]
